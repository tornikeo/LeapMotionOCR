# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import requests
from pathlib import Path
import zipfile
import cv2 as cv
from sklearn.cluster import KMeans

# %%
dfs = [[] for _ in range(10)]
for i in range(10):
    for k in range(100):
        df = pd.read_csv(f"training_data/stroke_{i}_{k+1:04}.csv", header=None)
        df.drop(df.columns[2], axis=1, inplace=True)
        # df = (df - df.min()) / (df.max()-df.min())
        df = (df - df.mean()) / (df.std())
        dfs[i].append(df)

# %%
LINE_BINS = 16
ANGLE_BINS = 16
BINS = LINE_BINS + ANGLE_BINS
def featurize_angle(df: pd.DataFrame):
    features = []
    for i in range(df.shape[0]-1):
        features.append(np.arctan2(df.iloc[i, 1], df.iloc[i, 0]))

    res = np.histogram(features, bins=ANGLE_BINS, range=(-np.pi, np.pi))[0]
    res = res / res.sum()
    return res

def featurize(df: pd.DataFrame):
    features = []
    ref = np.array((0,1))
    
    for i in range(df.shape[0]-1):
        dir = df.iloc[i+1] - df.iloc[i]
        norm = np.linalg.norm(dir)
        if norm == 0:
            continue
        # angle = np.arccos(np.dot(dir, ref) / norm)
        angle = np.dot(dir, ref) / norm
        features.append(angle)
    res = np.histogram(features, bins=LINE_BINS, range=(-1, 1))[0]
    res = res / res.sum()

    anglefeatures = featurize_angle(df)
    res = np.concatenate((res, anglefeatures))
    return res

# %%
test = []
num = 2
features = []
for k in range(90):
    features.append(featurize(dfs[num][k]))

clustercount = 2
km = KMeans(n_clusters=clustercount, n_init=10)
km.fit(features)
for i in range(clustercount):
    plt.bar(range(BINS), km.cluster_centers_[i])
    plt.title(f"Num: {num}, Cluster: {i}, Count: {np.count_nonzero(km.labels_ == i)}")
    plt.show()

width = 0.3       

# Plotting
# plt.bar(range(BINS), km.cluster_centers_[0] , width, label=f'Count: {np.count_nonzero(km.labels_ == 0)}')
# plt.bar(np.array(range(BINS)) + width, km.cluster_centers_[1], width, label=f'Count: {np.count_nonzero(km.labels_ == 1)}')
# plt.show()
# avg = features/90
# test.append(avg)
# plt.bar(range(BINS), avg)
# plt.title(str(num))
# plt.show()

# %%
fvs = []
clustercount = 1
for num in range(10):
    features = []
    for k in range(90):
        features.append(featurize(dfs[num][k]))

    km = KMeans(n_clusters=clustercount, n_init=10)
    km.fit(features)
    fvs += km.cluster_centers_.tolist()
    # fvs.append(km.cluster_centers_[0])
    # fvs.append(km.cluster_centers_[1])
    # plt.bar(range(BINS), avg)
    # plt.title(str(num))
    # plt.show()

# %%
from scipy.stats import chisquare
from scipy.special import kl_div
correct = 0
incorrect = 0

for num in range(10):
    for i in range(90, 100):
        df = dfs[num][i]
        tmp = featurize(df)

        scores = []
        for ti, template in enumerate(fvs):
            # score = chisquare(tmp, template)
            score = np.sum(kl_div(tmp, template))
            # scores.append(score.pvalue)
            scores.append(score)

        selected = np.argmin(scores)//clustercount
        # selected = np.argmax(scores)//2
        print(f"i: {i}, Num: {num}, Estimate: {selected}")
        if selected == num:
            correct += 1
        else:
            incorrect += 1

print(f"Correct: {correct}, Incorrect: {incorrect}, Accuracy: {correct/(correct+incorrect)}")
# Out:
# i: 90, Num: 0, Estimate: 0
# i: 91, Num: 0, Estimate: 0
# i: 92, Num: 0, Estimate: 0
# i: 93, Num: 0, Estimate: 0
# i: 94, Num: 0, Estimate: 0
# i: 95, Num: 0, Estimate: 0
# i: 96, Num: 0, Estimate: 6
# i: 97, Num: 0, Estimate: 0
# i: 98, Num: 0, Estimate: 8
# i: 99, Num: 0, Estimate: 0
# i: 90, Num: 1, Estimate: 2
# i: 91, Num: 1, Estimate: 7
# i: 92, Num: 1, Estimate: 1
# i: 93, Num: 1, Estimate: 1
# i: 94, Num: 1, Estimate: 7
# i: 95, Num: 1, Estimate: 1
# i: 96, Num: 1, Estimate: 1
# i: 97, Num: 1, Estimate: 1
# i: 98, Num: 1, Estimate: 1
# i: 99, Num: 1, Estimate: 2
# i: 90, Num: 2, Estimate: 2
# i: 91, Num: 2, Estimate: 2
# i: 92, Num: 2, Estimate: 2
# i: 93, Num: 2, Estimate: 2
# i: 94, Num: 2, Estimate: 2
# i: 95, Num: 2, Estimate: 2
# i: 96, Num: 2, Estimate: 2
# i: 97, Num: 2, Estimate: 2
# i: 98, Num: 2, Estimate: 2
# i: 99, Num: 2, Estimate: 2
# i: 90, Num: 3, Estimate: 3
# i: 91, Num: 3, Estimate: 3
# i: 92, Num: 3, Estimate: 3
# i: 93, Num: 3, Estimate: 3
# i: 94, Num: 3, Estimate: 3
# i: 95, Num: 3, Estimate: 3
# i: 96, Num: 3, Estimate: 3
# i: 97, Num: 3, Estimate: 3
# i: 98, Num: 3, Estimate: 3
# i: 99, Num: 3, Estimate: 3
# i: 90, Num: 4, Estimate: 4
# i: 91, Num: 4, Estimate: 4
# i: 92, Num: 4, Estimate: 4
# i: 93, Num: 4, Estimate: 4
# i: 94, Num: 4, Estimate: 6
# i: 95, Num: 4, Estimate: 6
# i: 96, Num: 4, Estimate: 6
# i: 97, Num: 4, Estimate: 4
# i: 98, Num: 4, Estimate: 6
# i: 99, Num: 4, Estimate: 4
# i: 90, Num: 5, Estimate: 5
# i: 91, Num: 5, Estimate: 5
# i: 92, Num: 5, Estimate: 5
# i: 93, Num: 5, Estimate: 2
# i: 94, Num: 5, Estimate: 5
# i: 95, Num: 5, Estimate: 5
# i: 96, Num: 5, Estimate: 5
# i: 97, Num: 5, Estimate: 5
# i: 98, Num: 5, Estimate: 5
# i: 99, Num: 5, Estimate: 6
# i: 90, Num: 6, Estimate: 6
# i: 91, Num: 6, Estimate: 6
# i: 92, Num: 6, Estimate: 6
# i: 93, Num: 6, Estimate: 9
# i: 94, Num: 6, Estimate: 6
# i: 95, Num: 6, Estimate: 6
# i: 96, Num: 6, Estimate: 6
# i: 97, Num: 6, Estimate: 6
# i: 98, Num: 6, Estimate: 6
# i: 99, Num: 6, Estimate: 6
# i: 90, Num: 7, Estimate: 7
# i: 91, Num: 7, Estimate: 7
# i: 92, Num: 7, Estimate: 7
# i: 93, Num: 7, Estimate: 9
# i: 94, Num: 7, Estimate: 7
# i: 95, Num: 7, Estimate: 7
# i: 96, Num: 7, Estimate: 7
# i: 97, Num: 7, Estimate: 7
# i: 98, Num: 7, Estimate: 7
# i: 99, Num: 7, Estimate: 7
# i: 90, Num: 8, Estimate: 8
# i: 91, Num: 8, Estimate: 8
# i: 92, Num: 8, Estimate: 8
# i: 93, Num: 8, Estimate: 3
# i: 94, Num: 8, Estimate: 8
# i: 95, Num: 8, Estimate: 8
# i: 96, Num: 8, Estimate: 6
# i: 97, Num: 8, Estimate: 8
# i: 98, Num: 8, Estimate: 8
# i: 99, Num: 8, Estimate: 8
# i: 90, Num: 9, Estimate: 6
# i: 91, Num: 9, Estimate: 9
# i: 92, Num: 9, Estimate: 9
# i: 93, Num: 9, Estimate: 3
# i: 94, Num: 9, Estimate: 9
# i: 95, Num: 9, Estimate: 9
# i: 96, Num: 9, Estimate: 9
# i: 97, Num: 9, Estimate: 9
# i: 98, Num: 9, Estimate: 9
# i: 99, Num: 9, Estimate: 9
# Correct: 82, Incorrect: 18, Accuracy: 0.82

# %%
num = 1
i = 90
plt.plot(dfs[num][i].iloc[:,0], dfs[num][i].iloc[:,1])
